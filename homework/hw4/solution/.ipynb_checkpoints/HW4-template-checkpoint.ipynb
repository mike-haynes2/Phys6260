# %% [markdown]
# # PHYS 6260: Homework 4, Your name

# %% [markdown]
# Below I show an example of how to create an animation in an notebook, which you will need for each part in the homework.

# %%
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.rcParams['animation.html'] = 'html5' # this is used to display animations in jupyter notebooks
#plt.rcParams['animation.ffmpeg_path'] = '/home/chaynes32/.local/lib/python3.10/site-packages/ffmpeg'

# %%
solutions = []
niter = 20
N = 100
allt = np.linspace(0,1,niter)
x = np.linspace(0,1,N)
for t in allt:
    solutions.append(np.sin(2 * np.pi * (x-t)))

# %%
ims = []
fig = plt.figure(figsize=[4,3])
plt.grid()

i = 0
plot_every = 1
for sol in solutions:
    if (i % plot_every == 0): # output frequency for frames  
        im = plt.plot(x, sol, 'k-', animated=True)
        plt.ylim(-1,1)
        ims.append(im)
    i+=1
ani = animation.ArtistAnimation(fig, ims, interval=100, blit=True,
                                repeat_delay=1000)
ani.save('ftcs.mp4')   
#ani
# Out:
# MovieWriter stderr:
# /tmp/tmp_p4hh4cp/temp.m4v: No such file or directory
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:236, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235 try:
# --> 236     yield self
#     237 finally:
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:1095, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1094         frame_number += 1
# -> 1095 writer.grab_frame(**savefig_kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:353, in MovieWriter.grab_frame(self, **savefig_kwargs)
#     352 # Save the figure data to the sink, using the frame format and dpi.
# --> 353 self.fig.savefig(self._proc.stdin, format=self.frame_format,
# ...
