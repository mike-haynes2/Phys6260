# %% [markdown]
# # Lecture 03/10: Introduction to Machine Learning
# ## Neural Networks
# ### Neural Network Overview
#
# #### Structure of a Neural Net
# A neural net includes several steps, divided into _layers_:
# 1. Input Layer (no processing, takes in input)
# 2. Processing with map into output Layer
#
# Data is usually normalized onto the unit interval.
#
# Processing involves applying some (nonlinear) function onto the mapped data:
#
# Linear Mapping: for input $\vec{x}$, can we predict the output $\vec{z}$:
#
# $g(\vec{x})$ is some function applied to the mapping $\mathbb{A}$,
#
# $\vec{z} = \mathbb{A} \cdot \vec{x}$, such that
#
# $\vec{z} = g( \mathbb{A} \cdot \vec{x} )$

# %% [markdown]
# #### Choice of mapping $g$
# - Mimicing the behavior of "neurons" (taken to be the connections between input and output data), some nonlinear map chooses whether a neuron "fires" and how sensitive that is to the input
# - Typical choice: Sigmoid function
# $g(p) = \frac{1}{1+e^{-\alpha p}}$, such that $z\in[0,1]$
# - Common choice is $\alpha=1$
# - There is a narrow range of non-linearity, so we can also pick $\alpha$ such that the inputs fall in the nonlinear range
# $\alpha = \frac{10}{n \max{|x_i|}}$

# %% [markdown]
# ## Implementation
# #### Training
# - We have $T$ pairs of $(x_k,y_k)$ coordinates that we can use to train our model
# - Important: remember that our y-values have to be scaled to (0,1), so they are in the same range that our function $g(p)$ maps to
# - Recall that $g$ is a scalar function:
#   $g(\mathbb{A}\cdot \vec{x}) = \vec{y}$
#   $\implies z_i = g([\mathbb{A}\cdot\vec{x}]_i) = g\left( \sum_j A_{ij} x_j \right)$
#
# - We seek the elements of $\mathbb{A}$
# - This can be expressed as a minimization problem, where we alter the matrix elements to achieve this agreement:
# - Defining the loss function
# $f(A_{ij}) = \left| g(\mathbb{A} x^k) - y^k \right|^2$
# - The learning is then perscribed by:
# $\vec{x} \leftarrow x - \eta \nabla u$
#
# We have the following example:

# %%
# an example of steepest (gradient) descent minimization

import numpy as np
import matplotlib.pyplot as plt

def rosenbrock(x0, x1, a, b):
    return (a - x0)**2 + b*(x1 - x0**2)**2

def drosdx(x, a, b):
    x0 = x[0]
    x1 = x[1]
    return np.array([-2.0*(a - x0) - 4.0*b*x0*(x1 - x0**2),
                     2.0*b*(x1 - x0**2)])

def inside(x, bounds):
    return ((x > bounds[:,0]) & (x < bounds[:,1])).all()

def main():

    xmin = -2.0
    xmax = 2.0
    ymin = -1.0
    ymax = 3.0

    a = 1.0
    b = 100.0

    N = 256
    x = np.linspace(xmin, xmax, N)
    y = np.linspace(ymin, ymax, N)

    x2d, y2d = np.meshgrid(x, y, indexing="ij")

    plt.imshow(np.log10(np.transpose(rosenbrock(x2d, y2d, a, b))), 
               origin="lower",
               extent=[xmin, xmax, ymin, ymax])

    plt.colorbar()
    plt.tight_layout()

    plt.savefig("min_2d_start.png", dpi=150)


    # do descent
    xp = np.array([-1.0, 1.5])
    xp_old = 1000*xp

    eps = 1.e-5

    eta = 0.002


    
    iter = 0
    bounds = np.array([[xmin, xmax], [ymin, ymax]])
    while np.linalg.norm(xp - xp_old) > eps and inside(xp, bounds):
        xp_old[:] = xp[:]

        ### In-class problem: Complete your implementation of steepest descent here
        grad_ = drosdx(xp_old, a, b)
        xp = xp_old - eta * grad_

        iter += 1
        if iter % 20 == 0:
            print(f"Iteration {iter}: Completed")
    
        plt.plot([xp_old[0], xp[0]], [xp_old[1], xp[1]], color="C1")

    plt.scatter([xp[0]], [xp[1]], marker="o", color="C1")    
    if not inside(xp, bounds):
        print(f"Exited because point {xp} exited the allocated bounds {bounds}")
        plt.title("Failed")
    else:
        print(f"Found minimum {xp} in {iter} iterations")
        plt.title("Success")

    plt.savefig("min_2d_descent.png", dpi=150)

if __name__ == "__main__":
    main()
# Out:
# Iteration 20: Completed
# Iteration 40: Completed
# Iteration 60: Completed
# Iteration 80: Completed
# Iteration 100: Completed
# Iteration 120: Completed
# Iteration 140: Completed
# Iteration 160: Completed
# Iteration 180: Completed
# Iteration 200: Completed
# Iteration 220: Completed
# Iteration 240: Completed
# Iteration 260: Completed
# Iteration 280: Completed
# Iteration 300: Completed
# Iteration 320: Completed
# Iteration 340: Completed
# Iteration 360: Completed
# Iteration 380: Completed
# Iteration 400: Completed
# Iteration 420: Completed
# Iteration 440: Completed
# Iteration 460: Completed
# Iteration 480: Completed
# Iteration 500: Completed
# Iteration 520: Completed
# Iteration 540: Completed
# Iteration 560: Completed
# Iteration 580: Completed
# Iteration 600: Completed
# Iteration 620: Completed
# Iteration 640: Completed
# Iteration 660: Completed
# Iteration 680: Completed
# Iteration 700: Completed
# Iteration 720: Completed
# Iteration 740: Completed
# Iteration 760: Completed
# Iteration 780: Completed
# Iteration 800: Completed
# Iteration 820: Completed
# Iteration 840: Completed
# Iteration 860: Completed
# Iteration 880: Completed
# Iteration 900: Completed
# Iteration 920: Completed
# Iteration 940: Completed
# Iteration 960: Completed
# Iteration 980: Completed
# Iteration 1000: Completed
# Iteration 1020: Completed
# Iteration 1040: Completed
# Iteration 1060: Completed
# Iteration 1080: Completed
# Iteration 1100: Completed
# Iteration 1120: Completed
# Iteration 1140: Completed
# Iteration 1160: Completed
# Iteration 1180: Completed
# Iteration 1200: Completed
# Iteration 1220: Completed
# Iteration 1240: Completed
# Iteration 1260: Completed
# Iteration 1280: Completed
# Iteration 1300: Completed
# Iteration 1320: Completed
# Iteration 1340: Completed
# Iteration 1360: Completed
# Iteration 1380: Completed
# Iteration 1400: Completed
# Iteration 1420: Completed
# Iteration 1440: Completed
# Iteration 1460: Completed
# Iteration 1480: Completed
# Iteration 1500: Completed
# Iteration 1520: Completed
# Iteration 1540: Completed
# Iteration 1560: Completed
# Iteration 1580: Completed
# Iteration 1600: Completed
# Iteration 1620: Completed
# Iteration 1640: Completed
# Iteration 1660: Completed
# Iteration 1680: Completed
# Iteration 1700: Completed
# Iteration 1720: Completed
# Iteration 1740: Completed
# Iteration 1760: Completed
# Iteration 1780: Completed
# Iteration 1800: Completed
# Iteration 1820: Completed
# Iteration 1840: Completed
# Iteration 1860: Completed
# Iteration 1880: Completed
# Iteration 1900: Completed
# Iteration 1920: Completed
# Iteration 1940: Completed
# Iteration 1960: Completed
# Iteration 1980: Completed
# Iteration 2000: Completed
# Iteration 2020: Completed
# Iteration 2040: Completed
# Iteration 2060: Completed
# Iteration 2080: Completed
# Iteration 2100: Completed
# Iteration 2120: Completed
# Iteration 2140: Completed
# Iteration 2160: Completed
# Iteration 2180: Completed
# Iteration 2200: Completed
# Iteration 2220: Completed
# Iteration 2240: Completed
# Iteration 2260: Completed
# Iteration 2280: Completed
# Iteration 2300: Completed
# Iteration 2320: Completed
# Iteration 2340: Completed
# Iteration 2360: Completed
# Iteration 2380: Completed
# Iteration 2400: Completed
# Iteration 2420: Completed
# Iteration 2440: Completed
# Iteration 2460: Completed
# Iteration 2480: Completed
# Iteration 2500: Completed
# Iteration 2520: Completed
# Iteration 2540: Completed
# Iteration 2560: Completed
# Iteration 2580: Completed
# Iteration 2600: Completed
# Iteration 2620: Completed
# Iteration 2640: Completed
# Iteration 2660: Completed
# Iteration 2680: Completed
# Iteration 2700: Completed
# Iteration 2720: Completed
# Iteration 2740: Completed
# Iteration 2760: Completed
# Iteration 2780: Completed
# Iteration 2800: Completed
# Iteration 2820: Completed
# Iteration 2840: Completed
# Iteration 2860: Completed
# Iteration 2880: Completed
# Iteration 2900: Completed
# Iteration 2920: Completed
# Iteration 2940: Completed
# Iteration 2960: Completed
# Iteration 2980: Completed
# Iteration 3000: Completed
# Iteration 3020: Completed
# Iteration 3040: Completed
# Iteration 3060: Completed
# Iteration 3080: Completed
# Iteration 3100: Completed
# Iteration 3120: Completed
# Iteration 3140: Completed
# Iteration 3160: Completed
# Iteration 3180: Completed
# Iteration 3200: Completed
# Iteration 3220: Completed
# Iteration 3240: Completed
# Iteration 3260: Completed
# Iteration 3280: Completed
# Iteration 3300: Completed
# Iteration 3320: Completed
# Iteration 3340: Completed
# Iteration 3360: Completed
# Iteration 3380: Completed
# Iteration 3400: Completed
# Iteration 3420: Completed
# Iteration 3440: Completed
# Iteration 3460: Completed
# Iteration 3480: Completed
# Iteration 3500: Completed
# Iteration 3520: Completed
# Iteration 3540: Completed
# Iteration 3560: Completed
# Iteration 3580: Completed
# Iteration 3600: Completed
# Iteration 3620: Completed
# Iteration 3640: Completed
# Iteration 3660: Completed
# Iteration 3680: Completed
# Iteration 3700: Completed
# Iteration 3720: Completed
# Iteration 3740: Completed
# Iteration 3760: Completed
# Iteration 3780: Completed
# Iteration 3800: Completed
# Iteration 3820: Completed
# Iteration 3840: Completed
# Iteration 3860: Completed
# Iteration 3880: Completed
# Iteration 3900: Completed
# Iteration 3920: Completed
# Iteration 3940: Completed
# Iteration 3960: Completed
# Iteration 3980: Completed
# Iteration 4000: Completed
# Iteration 4020: Completed
# Iteration 4040: Completed
# Iteration 4060: Completed
# Iteration 4080: Completed
# Iteration 4100: Completed
# Iteration 4120: Completed
# Iteration 4140: Completed
# Iteration 4160: Completed
# Iteration 4180: Completed
# Iteration 4200: Completed
# Iteration 4220: Completed
# Iteration 4240: Completed
# Iteration 4260: Completed
# Iteration 4280: Completed
# Iteration 4300: Completed
# Iteration 4320: Completed
# Iteration 4340: Completed
# Iteration 4360: Completed
# Iteration 4380: Completed
# Iteration 4400: Completed
# Iteration 4420: Completed
# Iteration 4440: Completed
# Iteration 4460: Completed
# Iteration 4480: Completed
# Iteration 4500: Completed
# Iteration 4520: Completed
# Iteration 4540: Completed
# Iteration 4560: Completed
# Iteration 4580: Completed
# Iteration 4600: Completed
# Iteration 4620: Completed
# Iteration 4640: Completed
# Iteration 4660: Completed
# Iteration 4680: Completed
# Iteration 4700: Completed
# Iteration 4720: Completed
# Iteration 4740: Completed
# Iteration 4760: Completed
# Iteration 4780: Completed
# Iteration 4800: Completed
# Iteration 4820: Completed
# Iteration 4840: Completed
# Iteration 4860: Completed
# Iteration 4880: Completed
# Iteration 4900: Completed
# Iteration 4920: Completed
# Iteration 4940: Completed
# Iteration 4960: Completed
# Iteration 4980: Completed
# Iteration 5000: Completed
# Iteration 5020: Completed
# Iteration 5040: Completed
# Iteration 5060: Completed
# Iteration 5080: Completed
# Iteration 5100: Completed
# Iteration 5120: Completed
# Iteration 5140: Completed
# Iteration 5160: Completed
# Iteration 5180: Completed
# Iteration 5200: Completed
# Iteration 5220: Completed
# Iteration 5240: Completed
# Iteration 5260: Completed
# Iteration 5280: Completed
# Iteration 5300: Completed
# Iteration 5320: Completed
# Iteration 5340: Completed
# Iteration 5360: Completed
# Found minimum [0.99444099 0.98889057] in 5361 iterations

# %% [markdown]
# #### Caveats
# - When you minimize with one set of training data, there is no guarantee that you are still minimized with respect to the previous sets
# - In practice, you feed the training data multiple times, in random order to the minimizer
# - Each pass is called an epoch
#
# #### Neural Net Minimization
# We are minimizing the function
# $$ f(A_{ij}) = |g(Ax^k) - y^k|^2 $$
# such that
# $$ (x^k,y^k) = ([x_1^k, x_2^k, \dots, x_n^k], [y_1^k, y_2^k, \dots, y_n^k]) \qquad .$$
# Each update would be:
# $$ A^{new}_{pq} = A_{pq} - \eta \frac{\partial f}{\partial A_{pq} } $$
# so
# $$ f(A_{ij}) = \sum_{i=1}^m \left [ g\left(\sum_{j=1}^n A_{ij} x_j \right ) - y_i\right ]^2 $$
#
# The derivative $\frac{\partial f}{\partial A_{ij}}$ is given by
# $$\frac{\partial f}{\partial A_{ij}} = 2(z_p - y_p) \alpha z_p (1-z_p)x_q$$
# where $\vec{z} = \mathbb{A}\cdot\vec{x}$ and $\alpha$ is the sigmoid parameter.
